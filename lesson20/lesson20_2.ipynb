# %% [markdown]
# ## 資料 >> groupby處理 >> unstake成樞紐分析

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame({'key1':['a', 'a', 'b', 'b', 'a'],
                  'key2':['one', 'two', 'one', 'two', 'one'],
                  'data1': np.random.randn(5),
                  'data2':np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.234688 -0.430901
# 1    a  two  1.310928 -0.187718
# 2    b  one -0.261812  0.455398
# 3    b  two  0.450773  0.369263
# 4    a  one  0.468222  2.023765

# %%
df.groupby(by="key1")[['data1','data2']].sum()
# Out:
#          data1     data2
# key1
# a     2.013839  1.405146
# b     0.188960  0.824660

# %%
df1 = df.groupby(by=['key1','key2']).sum()
df1.columns.name = "data"
df1
# Out:
# data          data1     data2
# key1 key2
# a    one   0.702910  1.592864
#      two   1.310928 -0.187718
# b    one  -0.261812  0.455398
#      two   0.450773  0.369263

# %%
df1.stack().unstack(level=['key2','data'])
# Out:
# key2       one                 two
# data     data1     data2     data1     data2
# key1
# a     0.702910  1.592864  1.310928 -0.187718
# b    -0.261812  0.455398  0.450773  0.369263

# %%
df1 = df.groupby(by=['key1','key2']).agg([("加總","sum"),("平均","mean")])
df1
# Out:
#               data1               data2
#                  加總        平均        加總        平均
# key1 key2
# a    one   0.702910  0.351455  1.592864  0.796432
#      two   1.310928  1.310928 -0.187718 -0.187718
# b    one  -0.261812 -0.261812  0.455398  0.455398
#      two   0.450773  0.450773  0.369263  0.369263
