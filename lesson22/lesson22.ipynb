# %%
from dotenv import load_dotenv
from google import genai

load_dotenv()
client = genai.Client()
response = client.models.generate_content(
    model="gemini-2.5-flash", contents="天空為什麼是藍的"
)
print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[16], line 6
#       4 load_dotenv()
#       5 client = genai.Client()
# ----> 6 response = client.models.generate_content(
#       7     model="gemini-2.5-flash", contents="天空為什麼是藍的"
#       8 )
#       9 print(response.text)
#
# File c:\Users\NETTLEFISH\miniconda3\envs\python24\Lib\site-packages\google\genai\models.py:5898, in Models.generate_content(self, model, contents, config)
#    5896 while remaining_remote_calls_afc > 0:
#    5897   i += 1
# -> 5898   response = self._generate_content(
#    5899       model=model, contents=contents, config=parsed_config
#    5900   )
#    5901   logger.info(f'AFC remote call {i} is done.')
#    5902   remaining_remote_calls_afc -= 1
#
# File c:\Users\NETTLEFISH\miniconda3\envs\python24\Lib\site-packages\google\genai\models.py:4838, in Models._generate_content(self, model, contents, config)
#    4835 request_dict = _common.convert_to_dict(request_dict)
#    4836 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4838 response = self._api_client.request(
#    4839     'post', path, request_dict, http_options
#    4840 )
#    4842 response_dict = '' if not response.body else json.loads(response.body)
#    4844 if self._api_client.vertexai:
#
# File c:\Users\NETTLEFISH\miniconda3\envs\python24\Lib\site-packages\google\genai\_api_client.py:1067, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1057 def request(
#    1058     self,
#    1059     http_method: str,
#    (...)   1062     http_options: Optional[HttpOptionsOrDict] = None,
#    1063 ) -> SdkHttpResponse:
#    1064   http_request = self._build_request(
#    1065       http_method, path, request_dict, http_options
#    1066   )
# -> 1067   response = self._request(http_request, stream=False)
#    1068   response_body = (
#    1069       response.response_stream[0] if response.response_stream else ''
#    1070   )
#    1071   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File c:\Users\NETTLEFISH\miniconda3\envs\python24\Lib\site-packages\google\genai\_api_client.py:958, in BaseApiClient._request(self, http_request, stream)
#     953 def _request(
#     954     self,
#     955     http_request: HttpRequest,
#     956     stream: bool = False,
#     957 ) -> HttpResponse:
# --> 958   return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\NETTLEFISH\miniconda3\envs\python24\Lib\site-packages\tenacity\__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File c:\Users\NETTLEFISH\miniconda3\envs\python24\Lib\site-packages\tenacity\__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File c:\Users\NETTLEFISH\miniconda3\envs\python24\Lib\site-packages\tenacity\__init__.py:418, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     416 retry_exc = self.retry_error_cls(fut)
#     417 if self.reraise:
# --> 418     raise retry_exc.reraise()
#     419 raise retry_exc from fut.exception()
#
# File c:\Users\NETTLEFISH\miniconda3\envs\python24\Lib\site-packages\tenacity\__init__.py:185, in RetryError.reraise(self)
#     183 def reraise(self) -> t.NoReturn:
#     184     if self.last_attempt.failed:
# --> 185         raise self.last_attempt.result()
#     186     raise self
#
# File c:\Users\NETTLEFISH\miniconda3\envs\python24\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\NETTLEFISH\miniconda3\envs\python24\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\NETTLEFISH\miniconda3\envs\python24\Lib\site-packages\tenacity\__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\NETTLEFISH\miniconda3\envs\python24\Lib\site-packages\google\genai\_api_client.py:948, in BaseApiClient._request_once(self, http_request, stream)
#     940 else:
#     941   response = self._httpx_client.request(
#     942       method=http_request.method,
#     943       url=http_request.url,
#    (...)    946       timeout=http_request.timeout,
#     947   )
# --> 948   errors.APIError.raise_for_response(response)
#     949   return HttpResponse(
#     950       response.headers, response if stream else [response.text]
#     951   )
#
# File c:\Users\NETTLEFISH\miniconda3\envs\python24\Lib\site-packages\google\genai\errors.py:104, in APIError.raise_for_response(cls, response)
#     102 status_code = response.status_code
#     103 if 400 <= status_code < 500:
# --> 104   raise ClientError(status_code, response_json, response)
#     105 elif 500 <= status_code < 600:
#     106   raise ServerError(status_code, response_json, response)
#
# ClientError: 400 INVALID_ARGUMENT. {'error': {'code': 400, 'message': 'API key not valid. Please pass a valid API key.', 'status': 'INVALID_ARGUMENT', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'API_KEY_INVALID', 'domain': 'googleapis.com', 'metadata': {'service': 'generativelanguage.googleapis.com'}}, {'@type': 'type.googleapis.com/google.rpc.LocalizedMessage', 'locale': 'en-US', 'message': 'API key not valid. Please pass a valid API key.'}]}}
